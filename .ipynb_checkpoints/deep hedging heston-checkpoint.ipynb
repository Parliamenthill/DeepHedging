# %%
import numpy as np 
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import norm
keras = tf.keras
from utils import utils 
from importlib import reload 
print(tf.__version__)
reload(utils)
# Out:
# 2.3.0
# <module 'utils.utils' from 'C:\\SongyanHou\\Study\\Codes\\DeepHedging\\utils\\utils.py'>

# %%
N = 100 # time disrectization    
S0 = 1.0 # initial value of the asset
T = 30/365 # maturity
dt = T / 100
strike = 1.0
option_type = 'eurocall'
if option_type == 'eurocall':
    payoff_function = lambda x : 0.5*(np.abs(x-strike)+x-strike) # European call option payoff

# %% [markdown]
# #### Heston
# $$
# dS_{t}={\sqrt  {V_{t}}}S_{t}\,dW_{t}^{S}
# $$
# $$
# dV_{t}=\kappa (\theta -V_{t})\,dt+\sigma {\sqrt  {V_{t}}}\,dW_{t}^{{\nu }}
# $$
# Feller condition
# $$
# 2\kappa \theta >\sigma ^{2}
# $$

# %%
import QuantLib as ql
# parameters from "Deep Hedging"
kappa = 1  # mean reversion strength
sigma = 2  # vol of vol
rho = -0.7  # corr between asset price and var
theta = 0.04

volatility = np.sqrt(theta)
v0 = theta # historical vols for the stock  
Ktrain = 10**5
print('Feller condition: ',2*kappa*theta - sigma**2)

price_path, vol_path = utils.simulate_Heston(Ktrain,N,T,rho,kappa,theta,sigma,S0,v0)
payoff = payoff_function(price_path[:,-1]) 
# path_all = np.concatenate([price_path, vol_path],axis = -1)

time_grid = np.linspace(0,T,N+1)
time_grid = time_grid[:,None]

L = (vol_path - theta) / kappa * (1 - np.exp(-kappa*(T - time_grid))) + theta * (T - time_grid)
vs_path = L
vs_path[:,1:] = vs_path[:,1:] + np.cumsum(vol_path[:,:-1],axis = 1) * dt

path_all = np.concatenate([price_path, vs_path],axis = -1)
# Out:
# Feller condition:  -3.92

# %%
plt.figure(figsize = [6,3])
plt.plot(price_path[:5,:,0].T, label = 'price - strike')
plt.title('Price')
# plt.legend()
plt.grid()
plt.show()

plt.figure(figsize = [6,3])
plt.plot(vol_path[:5,:,0].T, label = 'volatility')
# plt.legend()
plt.title('Volatility')
plt.grid()
plt.show()

# %% [markdown]
# ### Build the deep hedging dynamic

# %% [markdown]
# Value process
# $$
# V_{t} = \int_{0}^{t}H_{t}dS_{t} + \alpha \int_{0}^{t}(S_{t}dH_{t})^{2} \cdot \text{(trans_cost =True)}
# $$
# Objective function
# \begin{equation}
# \begin{split}
# \min_{H_{t}}\quad & E\bigg[(f(S_{T})-V_{T})^2\bigg] \\
# + &\beta E\bigg[\int_{0}^{T}(C_{t} - V_{t})^{2}dt\bigg] \cdot \text{(control_path =True)}
# \end{split}
# \end{equation}
#
# where $(C_{t})_{t\geq 0}$ is the call option price and $f$ is the payoff function.

# %%
def build_dynamic(m, N, control_path, trans_cost, model_type, loss_type):
    
    L = 3 # number of layers in strategy
    n = m + 15  # nodes in the first but last layers
    Networks = utils.build_network(m, n , L, N)
    Network0 = keras.layers.Dense(1, use_bias=False)

    price = keras.Input(shape=(N+1,m))   # S_{t}; t=0,..,N+1; (batch, N+1, m)
    benchmark_hedge = keras.Input(shape=(N+1,m))   # V_{t}; t=0,..,N+1; (batch, N+1, m)
    payoff = keras.Input(shape=(1))
    if control_path:
        inputs = [price, payoff, benchmark_hedge]
    else:
        inputs = [price, payoff]
    price_difference = price[:,1:,:] - price[:,:-1,:]  # dS_{t}; t=0,..,N; (batch, N, m)
    premium = Network0(tf.ones_like(price[:,0,:1])) # premium; (batch, 1)

    HEDGE = [None]*(N+1)
    HEDGE[0] = tf.zeros_like(price[:,0,:])
    STRATEGY = [None]*N
    for j in range(N):
        if model_type == 'Heston':
            log_price = tf.math.log(price[:,j,:1])
            vola = price[:,j,1:]
            I = tf.concat([log_price, vola], axis = -1)
        else:
            I = tf.math.log(price[:,j,:])
        STRATEGY[j] = Networks[j](I) # H_{t} = nn(S_{t}); (batch, m)
        
        cost = 0
        if trans_cost and j > 0: 
            cost = 0.005*((STRATEGY[j]- STRATEGY[j-1])*price[:,j,:])**2
            
        HEDGE[j+1] = HEDGE[j] + STRATEGY[j] * price_difference[:,j,:] - cost # dX_{t} = H_{t}dS_{t}; (batch, m)
        
        
    outputs = premium + tf.math.reduce_sum(HEDGE[-1],axis = -1, keepdims = True) # premium + \int_{0}^{T}H_{t}dS_{t}; (batch, m)
    model_hedge = keras.Model(inputs = inputs, outputs=outputs)
    if loss_type == 'mse':
        mse = tf.keras.losses.MeanSquaredError()
        model_hedge.add_loss(mse(outputs, payoff))   
    elif loss_type == 'es':
        alpha = 0.99
        loss = premium + 1/(1 - alpha)*tf.nn.relu(payoff - outputs)
        loss = tf.reduce_mean(loss)
        model_hedge.add_loss(loss)  
    
    if control_path:
        for j in range(N):
            mse = tf.keras.losses.MeanSquaredError()
            model_hedge.add_loss(10*mse(HEDGE[j]+premium, benchmark_hedge[:,j]))   
    
    return model_hedge, Network0, Networks

# %% [markdown]
# ### Train the model

# %%
control_path = False
if not control_path:
    split = int(Ktrain/2)
    xtrain = [path_all[:split], payoff[:split]]  # input be path_all
    ytrain = payoff[:split]*0  # output be payoff
    xtest = [path_all[split:], payoff[:split]]  # input be path_all
    ytest = payoff[split:]*0  # output be payoff
else:
    split = int(Ktrain/2)
    xtrain = [path_all[:split], payoff[:split], option_path[:split]]  # input be path_all
    ytrain = payoff[:split]*0  # output be payoff
    xtest = [path_all[split:], payoff[:split], option_path[split:]]  # input be path_all
    ytest = payoff[split:]*0  # output be payoff

# %%
def zeroloss(y_true, y_predict):
    return tf.reduce_sum(y_predict*0)

# %%
def experiments(loss_type):
    m = 2
    control_path = False
    trans_cost = False
    model_hedge, Network0, Networks = build_dynamic(m, N, control_path, trans_cost, 'Heston', loss_type)
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.005) # specify the optmizer 
    model_hedge.compile(optimizer = optimizer,loss=zeroloss) # specify the expected shortfall
    model_hedge.fit(x=xtrain,y=ytrain, epochs=20,verbose=True,batch_size=256) # train the model 
    hedge_output_train = model_hedge.predict(xtrain) # compute the output (deep replicate payoff) with trained model 
    hedge_output_test = model_hedge.predict(xtest) # compute the output (deep replicate payoff) with trained model
    return  model_hedge, Network0, Networks, hedge_output_train, hedge_output_test

# %%
model_hedge_mse, Network0_mse, Networks_mse, hedge_output_train_mse, hedge_output_test_mse = experiments('mse')
# Out:
# Epoch 1/20
# 196/196 [==============================] - 4s 21ms/step - loss: 0.3306
# Epoch 2/20
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0115
# Epoch 3/20
# 196/196 [==============================] - 4s 19ms/step - loss: 2.5735e-04
# Epoch 4/20
# 196/196 [==============================] - 4s 21ms/step - loss: 1.2397e-04
# Epoch 5/20
# 196/196 [==============================] - 4s 19ms/step - loss: 8.0181e-05
# Epoch 6/20
# 196/196 [==============================] - 4s 19ms/step - loss: 5.9243e-05
# Epoch 7/20
# 196/196 [==============================] - 4s 19ms/step - loss: 4.9287e-05
# Epoch 8/20
# 196/196 [==============================] - 4s 20ms/step - loss: 4.3527e-05
# Epoch 9/20
# 196/196 [==============================] - 4s 20ms/step - loss: 3.9446e-05
# Epoch 10/20
# 196/196 [==============================] - 4s 19ms/step - loss: 3.6593e-05
# Epoch 11/20
# 196/196 [==============================] - 4s 18ms/step - loss: 3.4526e-05
# Epoch 12/20
# 196/196 [==============================] - 4s 20ms/step - loss: 3.2859e-05
# Epoch 13/20
# 196/196 [==============================] - 4s 22ms/step - loss: 3.2136e-05: 0s - loss: 3.2145
# Epoch 14/20
# 196/196 [==============================] - 4s 19ms/step - loss: 3.1033e-05
# Epoch 15/20
# 196/196 [==============================] - 4s 19ms/step - loss: 3.0166e-05
# Epoch 16/20
# 196/196 [==============================] - 4s 20ms/step - loss: 2.9484e-05
# Epoch 17/20
# 196/196 [==============================] - 3s 18ms/step - loss: 2.8766e-05
# Epoch 18/20
# 196/196 [==============================] - 3s 17ms/step - loss: 2.8937e-05
# Epoch 19/20
# 196/196 [==============================] - 3s 17ms/step - loss: 2.8179e-05
# Epoch 20/20
# 196/196 [==============================] - 4s 18ms/step - loss: 2.7889e-05

# %%
model_hedge_es, Network0_es, Networks_es, hedge_output_train_es, hedge_output_test_es = experiments('es')
# Out:
# Epoch 1/20
# 196/196 [==============================] - 4s 22ms/step - loss: 113.5361
# Epoch 2/20
# 196/196 [==============================] - 4s 21ms/step - loss: 21.8953
# Epoch 3/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0893
# Epoch 4/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0744
# Epoch 5/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0647
# Epoch 6/20
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0580
# Epoch 7/20
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0515
# Epoch 8/20
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0474
# Epoch 9/20
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0436
# Epoch 10/20
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0409
# Epoch 11/20
# 196/196 [==============================] - 3s 16ms/step - loss: 0.0392
# Epoch 12/20
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0386
# Epoch 13/20
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0375
# Epoch 14/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0368
# Epoch 15/20
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0364
# Epoch 16/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0361
# Epoch 17/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0359
# Epoch 18/20
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0357
# Epoch 19/20
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0354
# Epoch 20/20
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0355

# %%
def plotplot(model_hedge, Network0, Networks, hedge_output_train, hedge_output_test):
    f,p = plt.subplots(1,2, figsize = [20,5], sharey = True)
    p[0].scatter(price_path[split:,-1,0], hedge_output_test[:,0], s = 1, alpha = 0.5, label = 'deep hedge test ')   # deep replicate payoff 
    p[1].scatter(price_path[:split,-1,0], hedge_output_train[:,0], s = 1, alpha = 0.5, label = 'deep hedge train')   # deep replicate payoff 
    # p[2].scatter(price_path[:,-1,0], delta_output[:,0], s = 1, alpha = 0.5, label = 'delta hedge')   # delta replicate payoff 
    for i in range(2):
        p[i].scatter(price_path[:,-1,0], payoff[:,0], s = 1, alpha = 0.5, label = 'real payoff')        # real payoff
        p[i].legend()
        p[i].grid()
    print(f"deep premium: {Network0(tf.ones([1,1])).numpy()[0,0]:{1}.{4}}")         # premium of deep hedge (truncted printing)

    calculation_date = ql.Date(1, 1, 2020)
    helper = utils.heston_value(calculation_date, v0, kappa, theta, sigma, rho,\
                       S0, strike, ql.Date(31, 1, 2020))
    # helper,_ = utils.BlackScholes(T, S0, strike, sigma, option_type)
    print(f"real premium: {helper:{1}.{4}}")           # real premium
    plt.figure(figsize = [6,4])
    plt.hist(hedge_output_train[:,0] - ytrain[:,0],bins = 100)
#     plt.xlim([-0.05, 0.15])
    plt.grid()
    plt.show()

# %% [markdown]
# ### Compared with delta hedging

# %%
plotplot(model_hedge_mse, Network0_mse, Networks_mse, hedge_output_train_mse, hedge_output_test_mse)
# Out:
# deep premium: 0.01705
# real premium: 0.01692

# %%
plotplot(model_hedge_es, Network0_es, Networks_es, hedge_output_train_es, hedge_output_test_es)
# Out:
# deep premium: 0.03383
# real premium: 0.01692

# %% [markdown]
# ### Digital

# %%
option_type = 'eurodigitalcall'
if option_type == 'eurodigitalcall':
    payoff_function = lambda x : (x-strike) > 0 # European digital call option payoff
payoff = payoff_function(price_path[:,-1]) 
# path_all = np.concatenate([price_path, vol_path],axis = -1)

time_grid = np.linspace(0,T,N+1)
time_grid = time_grid[:,None]

L = (vol_path - theta) / kappa * (1 - np.exp(-kappa*(T - time_grid))) + theta * (T - time_grid)
vs_path = L
vs_path[:,1:] = vs_path[:,1:] + np.cumsum(vol_path[:,:-1],axis = 1) * dt

path_all = np.concatenate([price_path, vs_path],axis = -1)

# %%
control_path = False
if not control_path:
    split = int(Ktrain/2)
    xtrain = [path_all[:split], payoff[:split]]  # input be path_all
    ytrain = payoff[:split]*0  # output be payoff
    xtest = [path_all[split:], payoff[:split]]  # input be path_all
    ytest = payoff[split:]*0  # output be payoff
else:
    split = int(Ktrain/2)
    xtrain = [path_all[:split], payoff[:split], option_path[:split]]  # input be path_all
    ytrain = payoff[:split]*0  # output be payoff
    xtest = [path_all[split:], payoff[:split], option_path[split:]]  # input be path_all
    ytest = payoff[split:]*0  # output be payoff

# %%
def experiments(loss_type):
    m = 2
    control_path = False
    trans_cost = False
    model_hedge, Network0, Networks = build_dynamic(m, N, control_path, trans_cost, 'Heston', loss_type)
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.005) # specify the optmizer 
    model_hedge.compile(optimizer = optimizer,loss=zeroloss) # specify the expected shortfall
    model_hedge.fit(x=xtrain,y=ytrain, epochs=50,verbose=True,batch_size=256) # train the model 
    hedge_output_train = model_hedge.predict(xtrain) # compute the output (deep replicate payoff) with trained model 
    hedge_output_test = model_hedge.predict(xtest) # compute the output (deep replicate payoff) with trained model
    return  model_hedge, Network0, Networks, hedge_output_train, hedge_output_test

# %%
model_hedge_mse, Network0_mse, Networks_mse, hedge_output_train_mse, hedge_output_test_mse = experiments('mse')
# Out:
# Epoch 1/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.4454
# Epoch 2/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.3252
# Epoch 3/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.1170
# Epoch 4/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0933
# Epoch 5/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0894
# Epoch 6/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0866
# Epoch 7/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0841
# Epoch 8/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0821
# Epoch 9/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0805
# Epoch 10/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0792
# Epoch 11/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0780
# Epoch 12/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0770
# Epoch 13/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0760
# Epoch 14/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0750
# Epoch 15/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0742
# Epoch 16/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.0734
# Epoch 17/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0728
# Epoch 18/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0718
# Epoch 19/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0712
# Epoch 20/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0706
# Epoch 21/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0698
# Epoch 22/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0691
# Epoch 23/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0685
# Epoch 24/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0680: 0s - loss: 0.
# Epoch 25/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0674
# Epoch 26/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0667
# Epoch 27/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0661
# Epoch 28/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0659
# Epoch 29/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0654
# Epoch 30/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0649
# Epoch 31/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0646
# Epoch 32/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0641
# Epoch 33/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0637
# Epoch 34/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0634
# Epoch 35/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0626
# Epoch 36/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0624
# Epoch 37/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0620
# Epoch 38/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0617
# Epoch 39/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0614
# Epoch 40/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0609
# Epoch 41/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0603
# Epoch 42/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0599
# Epoch 43/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0598
# Epoch 44/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0593
# Epoch 45/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0591
# Epoch 46/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0589
# Epoch 47/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0585
# Epoch 48/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0583
# Epoch 49/50
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0578
# Epoch 50/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.0575

# %%
model_hedge_es, Network0_es, Networks_es, hedge_output_train_es, hedge_output_test_es = experiments('es')
# Out:
# Epoch 1/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.0158: 0s -
# Epoch 2/50
# 196/196 [==============================] - 4s 21ms/step - loss: 1.0021
# Epoch 3/50
# 196/196 [==============================] - 4s 21ms/step - loss: 1.0011
# Epoch 4/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0011
# Epoch 5/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0012
# Epoch 6/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9999
# Epoch 7/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0006
# Epoch 8/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0001
# Epoch 9/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9990
# Epoch 10/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9983
# Epoch 11/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9974
# Epoch 12/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9980
# Epoch 13/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.9976
# Epoch 14/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.9986
# Epoch 15/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9956
# Epoch 16/50
# 196/196 [==============================] - 5s 23ms/step - loss: 0.9949: 0s - lo
# Epoch 17/50
# 196/196 [==============================] - 4s 22ms/step - loss: 0.9969
# Epoch 18/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9955
# Epoch 19/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9941
# Epoch 20/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9933
# Epoch 21/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9936
# Epoch 22/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9932
# Epoch 23/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9941
# Epoch 24/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9913
# Epoch 25/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9937
# Epoch 26/50
# 196/196 [==============================] - 4s 23ms/step - loss: 0.9912
# Epoch 27/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.9921
# Epoch 28/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9906
# Epoch 29/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9908
# Epoch 30/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9908
# Epoch 31/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9911
# Epoch 32/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9887
# Epoch 33/50
# 196/196 [==============================] - 4s 22ms/step - loss: 0.9884
# Epoch 34/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9898
# Epoch 35/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9876
# Epoch 36/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9877
# Epoch 37/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9885
# Epoch 38/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9873
# Epoch 39/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9864
# Epoch 40/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9868
# Epoch 41/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.9872
# Epoch 42/50
# 196/196 [==============================] - 5s 24ms/step - loss: 0.9860
# Epoch 43/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.9861
# Epoch 44/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9854
# Epoch 45/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.9857
# Epoch 46/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9851
# Epoch 47/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9837
# Epoch 48/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9847
# Epoch 49/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9847
# Epoch 50/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9859

# %%
plotplot(model_hedge_mse, Network0_mse, Networks_mse, hedge_output_train_mse, hedge_output_test_mse)
# Out:
# deep premium: 0.6778
# real premium: 0.01692

# %%
plotplot(model_hedge_es, Network0_es, Networks_es, hedge_output_train_es, hedge_output_test_es)
# Out:
# deep premium: 0.9812
# real premium: 0.01692
